# %% [markdown]
# ## Principle Component Analysis (PCA) - Low Income Population in City of Toronto

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import os

# %% [markdown]
# ## Importing data

# %%
os.chdir('/Users/hadi/Documents/Professional_development/DS/INSIGHT/Project/Data/Data_pro')
df=pd.read_csv('Data_All_sorted_alpha_MVP_V6.csv')
df.head()
# Out:
#                   Neighbourhood Year  Home price  Change in housing pricing  \
# 0               Agincourt-North  Six    234855.0                   0.383812
# 1  Agincourt-South-Malvern-West  Six    245759.0                   0.364585
# 2                     Alderwood  Six    252745.0                   0.433282
# 3                         Annex  Six    592630.0                   0.457992
# 4             Banbury-Don-Mills  Six    410468.0                   0.475760
#
#    Low income population  Change in low income pop  Total Area  \
# 0                  29880                  0.000369         7.3
# 1                  21370                 -0.038545         7.9
# 2                  11635                 -0.012767         5.0
# 3                  26020                  0.174658         2.8
# 4                  25000                  0.056200        10.0
#
#    Total Population  Pop  25 - 34 years  Recent Immigrants  TTC Stops  \
# 0             30160                3920               4265         90
# 1             21565                2850               3060        121
# 2             11655                1370                290         56
# 3             27480                6760               1260         86
# 4             25435                2790               2400        125
#
#    Health Providers  Businesses  Social Housing Units  Rent Bank Applicants  \
# 0                17         295                    77                     2
# 1                79        1399                   170                    12
# 2                12         312                    85                     4
# 3               192        2322                  1065                    11
# 4                65         735                   304                    21
#
#    Future_change_low_income_pop  Future_Change_housing_pricing  Label
# 0                     -0.000501                        0.285052   GRE
# 1                      0.013172                        0.307456   GRE
# 2                     -0.000418                        0.338412   GRE
# 3                      0.076460                        0.372706  YELL
# 4                      0.006208                        0.369330  YELL

# %% [markdown]
# ## Standardize the Data

# %%
df.index = df.Neighbourhood
features = ['Home price','Change in housing pricing','Low income population',\
                           'Change in low income pop','Total Area','Total Population',\
                           'Pop  25 - 34 years','Recent Immigrants','TTC Stops','Health Providers','Businesses',\
                           'Social Housing Units','Rent Bank Applicants']
x = df.loc[:, features].values
y = df.loc[:,['Future_change_low_income_pop']].values

x = StandardScaler().fit_transform(x)

pd.DataFrame(data = x, columns = features).head()
# Out:
#    Home price  Change in housing pricing  Low income population  \
# 0   -0.915485                   0.030415               1.344126
# 1   -0.845050                  -0.211197               0.372085
# 2   -0.799924                   0.652079              -0.739880
# 3    1.395576                   0.962590               0.903224
# 4    0.218893                   1.185874               0.786716
#
#    Change in low income pop  Total Area  Total Population  Pop  25 - 34 years  \
# 0                 -0.047602    0.590805          1.354236            0.547734
# 1                 -0.285160    0.720826          0.363464           -0.011531
# 2                 -0.127793    0.092391         -0.778893           -0.785094
# 3                  1.016391   -0.384353          1.045304            2.032138
# 4                  0.293235    1.175900          0.809571           -0.042892
#
#    Recent Immigrants  TTC Stops  Health Providers  Businesses  \
# 0           1.672921   0.435214         -0.538331   -0.389405
# 1           0.876703   1.088226          1.217991    1.344868
# 2          -0.953607  -0.280994         -0.679970   -0.362700
# 3          -0.312668   0.350954          4.419028    2.794809
# 4           0.440600   1.172486          0.821402    0.301791
#
#    Social Housing Units  Rent Bank Applicants
# 0             -0.817120             -0.865982
# 1             -0.685879             -0.114385
# 2             -0.805830             -0.715663
# 3              0.577144             -0.189545
# 4             -0.496778              0.562052

# %% [markdown]
# ## PCA Projection to 2D

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
principalDf.head(5)
# Out:
#    principal component 1  principal component 2
# 0               1.570817              -1.154259
# 1               1.686605               0.028293
# 2              -1.830872              -0.230938
# 3               3.388365               4.488052
# 4               1.802327               0.328742

# %%
df[['Future_change_low_income_pop']].head()
# Out:
#                               Future_change_low_income_pop
# Neighbourhood
# Agincourt-North                                  -0.000501
# Agincourt-South-Malvern-West                      0.013172
# Alderwood                                        -0.000418
# Annex                                             0.076460
# Banbury-Don-Mills                                 0.006208

# %%
#finalDf = pd.concat([principalDf, df[['Future_change_low_income_pop']]],axis=1)
#finalDf.head(5)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.41288884, 0.1500238 ])

# %% [markdown]
# ### Making sure that 95% of the variance is retained:

# %%
pca = PCA(.90)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents)
principalDf.head(5)
# Out:
#           0         1         2         3         4         5         6
# 0  1.570817 -1.154259  0.340894 -0.447414 -0.135745  1.847786  1.080012
# 1  1.686605  0.028293  1.224947  0.837793 -0.497800  0.044838 -0.566684
# 2 -1.830872 -0.230938  0.610815  0.780392  0.822959  0.254790  0.303202
# 3  3.388365  4.488052 -0.256609  0.594436 -1.414713 -0.339125 -1.280853
# 4  1.802327  0.328742  1.109261  1.018823  0.124864  0.844730  0.120056

# %% [markdown]
# This shows for retaining 90% of the varience 6 components are required in the model.

# %%
import researchpy as rp
corr_type, corr_matrix, corr_ps = rp.corr_case(df[['Future_change_low_income_pop','Home price','Change in housing pricing','Low income population',\
                           'Change in low income pop','Total Area','Total Population',\
                           'Pop  25 - 34 years','Recent Immigrants','TTC Stops','Health Providers','Businesses',\
                           'Social Housing Units','Rent Bank Applicants']])

# %%
corr_matrix
# Out:
#                              Future_change_low_income_pop Home price  \
# Future_change_low_income_pop                            1     0.1725
# Home price                                         0.1725          1
# Change in housing pricing                          0.1164     0.0725
# Low income population                              0.1228    -0.1717
# Change in low income pop                           0.5879     0.1353
# Total Area                                         0.0662     -0.185
# Total Population                                    0.134     -0.168
# Pop  25 - 34 years                                 0.4473      0.043
# Recent Immigrants                                  0.0434    -0.2959
# TTC Stops                                          0.1223    -0.1408
# Health Providers                                     0.18     0.2457
# Businesses                                         0.4364     0.1314
# Social Housing Units                               0.2986    -0.1244
# Rent Bank Applicants                               0.0032    -0.4282
#
#                              Change in housing pricing Low income population  \
# Future_change_low_income_pop                    0.1164                0.1228
# Home price                                      0.0725               -0.1717
# Change in housing pricing                            1               -0.1591
# Low income population                          -0.1591                     1
# Change in low income pop                        0.0662                0.2294
# Total Area                                     -0.1395                0.5999
# Total Population                               -0.1583                0.9909
# Pop  25 - 34 years                              0.0322                0.7656
# Recent Immigrants                              -0.0841                 0.755
# TTC Stops                                      -0.1083                0.6609
# Health Providers                                0.1433                0.4443
# Businesses                                      0.1935                0.4053
# Social Housing Units                            0.0044                0.3482
# Rent Bank Applicants                           -0.1148                0.4721
#
#                              Change in low income pop Total Area  \
# Future_change_low_income_pop                   0.5879     0.0662
# Home price                                     0.1353     -0.185
# Change in housing pricing                      0.0662    -0.1395
# Low income population                          0.2294     0.5999
# Change in low income pop                            1     0.1902
# Total Area                                     0.1902          1
# Total Population                               0.2327     0.6006
# Pop  25 - 34 years                             0.4225     0.3043
# Recent Immigrants                              0.1281     0.3187
# TTC Stops                                      0.1637     0.8035
# Health Providers                               0.1901     0.2139
# Businesses                                      0.319     0.3607
# Social Housing Units                           0.1729     0.0173
# Rent Bank Applicants                          -0.0224     0.3354
#
#                              Total Population Pop  25 - 34 years  \
# Future_change_low_income_pop            0.134             0.4473
# Home price                             -0.168              0.043
# Change in housing pricing             -0.1583             0.0322
# Low income population                  0.9909             0.7656
# Change in low income pop               0.2327             0.4225
# Total Area                             0.6006             0.3043
# Total Population                            1             0.7828
# Pop  25 - 34 years                     0.7828                  1
# Recent Immigrants                      0.7392             0.5506
# TTC Stops                              0.6658              0.424
# Health Providers                       0.4472             0.4961
# Businesses                             0.4165              0.609
# Social Housing Units                   0.3576             0.5311
# Rent Bank Applicants                   0.4713             0.3037
#
#                              Recent Immigrants TTC Stops Health Providers  \
# Future_change_low_income_pop            0.0434    0.1223             0.18
# Home price                             -0.2959   -0.1408           0.2457
# Change in housing pricing              -0.0841   -0.1083           0.1433
# Low income population                    0.755    0.6609           0.4443
# Change in low income pop                0.1281    0.1637           0.1901
# Total Area                              0.3187    0.8035           0.2139
# Total Population                        0.7392    0.6658           0.4472
# Pop  25 - 34 years                      0.5506     0.424           0.4961
# Recent Immigrants                            1    0.3741           0.3232
# TTC Stops                               0.3741         1           0.4367
# Health Providers                        0.3232    0.4367                1
# Businesses                              0.2362    0.6068           0.6877
# Social Housing Units                    0.2656    0.1326           0.1548
# Rent Bank Applicants                    0.4778    0.3839           0.1139
#
#                              Businesses Social Housing Units  \
# Future_change_low_income_pop     0.4364               0.2986
# Home price                       0.1314              -0.1244
# Change in housing pricing        0.1935               0.0044
# Low income population            0.4053               0.3482
# Change in low income pop          0.319               0.1729
# Total Area                       0.3607               0.0173
# Total Population                 0.4165               0.3576
# Pop  25 - 34 years                0.609               0.5311
# Recent Immigrants                0.2362               0.2656
# TTC Stops                        0.6068               0.1326
# Health Providers                 0.6877               0.1548
# Businesses                            1               0.3456
# Social Housing Units             0.3456                    1
# Rent Bank Applicants             0.1348               0.2926
#
#                              Rent Bank Applicants
# Future_change_low_income_pop               0.0032
# Home price                                -0.4282
# Change in housing pricing                 -0.1148
# Low income population                      0.4721
# Change in low income pop                  -0.0224
# Total Area                                 0.3354
# Total Population                           0.4713
# Pop  25 - 34 years                         0.3037
# Recent Immigrants                          0.4778
# TTC Stops                                  0.3839
# Health Providers                           0.1139
# Businesses                                 0.1348
# Social Housing Units                       0.2926
# Rent Bank Applicants                            1
